# %% [markdown]
# # Training word embeddings with the SGNS algorithm
#
# In this notebook, we'll see a PyTorch implementation of a well-known training algorithm for word embeddings, Mikolov's [Skip-gram with negative sampling](https://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf).
#
# Please note that the example is somewhat incomplete, because in a realistic implementation we would also *save* the embeddings when training is finished. In this implementation, we'll just print the similarities to some test instances.

# %%
import torch
import torch.nn as nn

import numpy as np

import sys, time, os
from collections import Counter

# %% [markdown]
# If you'd like to run the code, download [this package](http://www.cse.chalmers.se/~richajo/dit865/slask/files/wikipedia_small.zip) and unzip it. [Colab users: it can be a bit difficult to download large files to the local directory in Colab, so if you have problems executing the following cell because the download gets stuck, you might need to mount a Drive directory instead.]

# %%
# !rm -rf wikipedia* *.zip*
# !wget http://www.cse.chalmers.se/~richajo/dit865/slask/files/wikipedia_small.zip
# !unzip wikipedia_small.zip
# !ls
# Out:
# --2020-04-08 07:34:27--  http://www.cse.chalmers.se/~richajo/dit865/slask/files/wikipedia_small.zip
# Resolving www.cse.chalmers.se (www.cse.chalmers.se)... 129.16.221.33
# Connecting to www.cse.chalmers.se (www.cse.chalmers.se)|129.16.221.33|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 48419133 (46M) [application/zip]
# Saving to: ‘wikipedia_small.zip’
#
# wikipedia_small.zip 100%[===================>]  46.18M  2.45MB/s    in 29s
#
# 2020-04-08 07:34:56 (1.58 MB/s) - ‘wikipedia_small.zip’ saved [48419133/48419133]
#
# Archive:  wikipedia_small.zip
#    creating: wikipedia_small/
#   inflating: wikipedia_small/wikipedia.txt
# sample_data  wikipedia_small  wikipedia_small.zip

# %% [markdown]
# ## Preliminaries: building the vocabulary and negative sampling table
#
# We will first make a function that goes through the training corpus and finds the most frequent words, which will be used for the vocabulary. A special dummy token will be used as a stand-in for the words that are less frequent.
#
# In addition, we will create the table that will be used for *negative sampling*. Each word will be sampled with a probability that is proportional to its frequency to the power of a constant (called `ns_exp` here). Sampling words randomly can be a bit tricky to implement efficiently, and we'll use a trick that was used in the `word2vec` software: we'll make a large array where each word will occur a number of times that is roughly proportional to its probability.

# %%
def make_ns_table(params):
    corpus = params['corpus']
    voc_size = params['voc-size']
    ns_table_size = params['ns-table-size']
    unk_str = params['unknown-str']
    lowercase = params['lowercase']
    ns_exp = params['ns-exp']

    # This is what we'll use to store the frequencies.
    freqs = Counter()

    print('Building vocabulary and sampling table...')    

    # First, build a full frequency table from the whole corpus.
    with open(corpus) as f:
        for i, line in enumerate(f, 1):
            if lowercase:
                line = line.lower()
            freqs.update(line.split())
            if i % 50000 == 0:
                sys.stdout.write('.')
                sys.stdout.flush()
            if i % 1000000 == 0:
                sys.stdout.write(' ')
                sys.stdout.write(str(i))
                sys.stdout.write('\n')
                sys.stdout.flush()
    print()

    # Sort the frequencies, then select the most frequent words as the vocabulary.
    freqs_sorted = sorted(freqs.items(),
                          key=lambda p: (p[1], p[0]),
                          reverse=True)
    if len(freqs_sorted) > voc_size-1:
        sum_freq_pruned = sum(f for _, f in freqs_sorted[voc_size-1:])
    else:
        sum_freq_pruned = 1

    # We'll add a special dummy to represent the occurrences of low-frequency words.
    freqs_sorted = [(unk_str, sum_freq_pruned)] + freqs_sorted[:voc_size-1]

    # Now, we'll compute the negative sampling table.
    # The negative sampling probabilities are proportional to the frequencies
    # to the power of a constant (typically 0.75).
    ns_table = {}
    sum_freq = 0
    for w, freq in freqs_sorted:
        ns_freq = freq ** ns_exp
        ns_table[w] = ns_freq
        sum_freq += ns_freq

    # Convert the negative sampling probabilities to integers, in order to make
    # sampling a bit faster and easier.
    # We return a list of tuples consisting of:
    # - the word
    # - its frequency in the training data
    # - the number of positions reserved for this word in the negative sampling table
    scaler = ns_table_size / sum_freq
    return [(w, freq, int(round(ns_table[w]*scaler))) for w, freq in freqs_sorted]

# %% [markdown]
# And then two utility functions to load and save the negative sampling table.

# %%
def load_ns_table(filename):
    with open(filename) as f:
        out = []
        for l in f:
            t = l.split()
            out.append((t[0], int(t[1]), int(t[2])))
        return out

def save_ns_table(table, filename):
    with open(filename, 'w') as f:
        for w, fr, ns in table:
            print(f'{w} {fr} {ns}', file=f)

# %% [markdown]
# ## Generating target–context pairs
#
# The following class is used to go through the training file line by line, and generate positive training instances (pairs consisting of a target word and a context word). Here, we will use all the preprocessing intricacies described in [Mikolov's paper](https://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf).
#
# The `batches` method will generate one batch at a time, containing a number of positive training instances coded as integers. The negative training instances will be created elsewhere.

# %%
class SGNSContextGenerator:

    def __init__(self, ns_table, params):

        # The name of the training file.
        self.corpus = params['corpus']
        
        # The string-to-integer mapping for the vocabulary.
        self.voc = { w:i for i, (w, _, _ ) in enumerate(ns_table) }

        # The number of positive instances we'll create in each batch.
        self.batch_size = params['batch-size']

        # The maximal width of the context window.
        self.ctx_width = params['context-width']

        # Whether we should 
        self.lowercase = params['lowercase']
        
        self.word_count = 0
        
        # We define the pruning probabilities for each word as in Mikolov's paper.
        total_freq = sum(f for _, f, _ in ns_table)
        self.prune_probs = {}
        for w, f, _ in ns_table:
            self.prune_probs[w] = 1 - np.sqrt(params['prune-threshold'] * total_freq / f)

    def prune(self, tokens):
        ps = np.random.random(size=len(tokens))
        # Remove some words from the input with probabilities defined by their frequencies.
        return [ w for w, p in zip(tokens, ps) if p >= self.prune_probs.get(w, 0) ]

    def batches(self):

        widths = np.random.randint(1, self.ctx_width+1, size=self.batch_size)
        width_ix = 0

        self.word_count = 0
        
        with open(self.corpus) as f:
            out_t = []
            out_c = []
            for line in f:

                # Process one line: lowercase and split into tokens.
                if self.lowercase:
                    line = line.lower()
                tokens = line.split()
                self.word_count += len(tokens)

                # Remove some words, then encode as integers.
                encoded = [ self.voc.get(t, 0) for t in self.prune(tokens) ]

                for i, t in enumerate(encoded):

                    # The context width is selected uniformly between 1 and the maximal width.
                    w = widths[width_ix]
                    width_ix += 1

                    # Compute start and end positions for the context.
                    start = max(0, i-w)
                    end = min(i+w+1, len(encoded))

                    # Finally, generate target--context pairs.
                    for j in range(start, end):
                        if j != i:
                            out_t.append(encoded[i])
                            out_c.append(encoded[j])
                            
                            # If we've generate enough pairs, yield a batch.
                            # Each batch is a list of targets and a list of corresponding contexts.
                            if len(out_t) == self.batch_size:
                                yield out_t, out_c
                                
                                # After coming back, reset the batch.
                                widths = np.random.randint(1, self.ctx_width+1, size=self.batch_size)
                                width_ix = 0
                                out_t = []
                                out_c = []
                    
            print('End of file.')
            if len(out_t) > 0:
                # Yield the final batch.
                yield out_t, out_c

# %% [markdown]
# ## Defining the model
#
# Next, we implement the neural network that defines the model. The parameters just consist of two sets of embeddings: one for the target words, and one for the contexts.
#
# The forward step is fairly trivial: we just compute the dot products of the target and context embeddings. As usual, the most annoying part is to keep track of the tensor shapes.
#
# We also add a couple of methods that allow us to inspect the model: computing the cosine similarity between the embeddings for two words, and finding the nearest neighbor lists of a set of words.

# %%
class SGNSModel(nn.Module):

    def __init__(self, voc, params):
        super().__init__()
        
        voc_size = len(voc)
        
        # Target word embeddings
        self.w = nn.Embedding(voc_size, params['emb-dim'])
        # Context embeddings
        self.c = nn.Embedding(voc_size, params['emb-dim'])
        
        # Some things we need to print nearest neighbor lists for diagnostics.
        self.voc = voc
        self.ivoc = { i:w for w, i in voc.items() }

    def forward(self, tgt, ctx):       
        # tgt is a 1-dimensional tensor containing target word ids
        # ctx is a 2-dimensional tensor containing positive and negative context ids for each target
        
        # Look up the embeddings for the target words.
        # shape: (batch size, embedding dimension)
        tgt_emb = self.w(tgt)
        
        n_batch, emb_dim = tgt_emb.shape
        n_ctx = ctx.shape[1]
        
        # View this as a 3-dimensional tensor, with
        # shape (batch size, 1, embedding dimension)
        tgt_emb = tgt_emb.view(n_batch, 1, emb_dim)

        # Look up the embeddings for the positive and negative context words.
        # shape: (batch size, nbr contexts, emb dim)
        ctx_emb = self.c(ctx)

        # Transpose the tensor for matrix multiplication
        # shape: (batch size, emb dim, nbr contexts)
        ctx_emb = ctx_emb.transpose(1, 2)

        # Compute the dot products between target word embeddings and context
        # embeddings. We express this as a batch matrix multiplication (bmm).
        # shape: (batch size, 1, nbr contexts)
        dots = tgt_emb.bmm(ctx_emb)

        # View this result as a 2-dimensional tensor.
        # shape: (batch size, nbr contexts)
        dots = dots.view(n_batch, n_ctx)

        return dots
    
    
    def nearest_neighbors(self, words, n_neighbors):
        
        # Encode the words as integers, and put them into a PyTorch tensor.
        words_ix = torch.as_tensor([self.voc[w] for w in words])
        
        # Look up the embeddings for the test words.
        voc_size, emb_dim = self.w.weight.shape
        test_emb = self.w(words_ix).view(len(words), 1, emb_dim)

        # Also, get the embeddings for all words in the vocabulary.
        all_emb = self.w.weight.view(1, voc_size, emb_dim)

        # We'll use a cosine similarity function to find the most similar words.
        # The .view kludgery above is needed for the batch-wise cosine similarity.
        sim_func = nn.CosineSimilarity(dim=2)
        scores = sim_func(test_emb, all_emb)
        # The shape of scores is (nbr of test words, total number of words)
                
        # Find the top-scoring columns in each row.
        if not n_neighbors:
            n_neighbors = self.n_testwords_neighbors
        near_nbr = scores.topk(n_neighbors+1, dim=1)
        values = near_nbr.values[:,1:]
        indices = near_nbr.indices[:, 1:]
        
        # Finally, map word indices back to strings, and put the result in a list.
        out = []
        for ixs, vals in zip(indices, values):
            out.append([ (self.ivoc[ix.item()], val.item()) for ix, val in zip(ixs, vals) ])
        return out
        
        
    def cosine_similarity(self, word1, word2):        
        # We just look up the two embeddings and use PyTorch's built-in cosine similarity.
        v1 = self.w(torch.as_tensor(self.voc[word1]))
        v2 = self.w(torch.as_tensor(self.voc[word2]))
        sim = nn.CosineSimilarity(dim=0)
        return sim(v1, v2).item()

# %% [markdown]
# ## Training
#
# The following class contains the training loop: it creates a batch of positive target–context pairs, generates negative samples, and then updates the embedding model.

# %%
class SGNSTrainer:

    def __init__(self, instance_gen, model, ns_table, params):
        self.instance_gen = instance_gen
        self.model = model
        self.n_epochs = params['n-epochs']
        self.max_words = params.get('max-words')
        n_batch = params['batch-size']
        self.n_ns = params['n-neg-samples']

        if params['optimizer'] == 'adam':
            self.optimizer = torch.optim.Adam(self.model.parameters(), lr=params['lr'])
        elif params['optimizer'] == 'sgd':
            self.optimizer = torch.optim.SGD(self.model.parameters(), lr=params['lr'])

        # We'll use a binary cross-entropy loss, since we have a binary classification problem:
        # distinguishing positive from negative contexts.
        self.loss = nn.BCEWithLogitsLoss()

        # Build the negative sampling table.
        ns_table_expanded = []
        for i, (_, _, count) in enumerate(ns_table):
            ns_table_expanded.extend([i] * count)
        self.ns_table = torch.as_tensor(ns_table_expanded)
        
        # Define the "gold standard" that we'll use to compute the loss.
        # It consists of a column of ones, and then a number of columns of zeros.
        # This structure corresponds to the positive and negative contexts, respectively.
        y_pos = torch.ones((n_batch, 1))
        y_neg = torch.zeros((n_batch, self.n_ns))
        self.y = torch.cat([y_pos, y_neg], dim=1)

        # Some things we need to print nearest neighbor lists for diagnostics.
        #self.voc = instance_gen.voc
        #self.ivoc = { i:w for w, i in self.voc.items() }
        self.testwords = params['testwords']
        self.n_testwords_neighbors = params['n-testwords-neighbors']

        self.epoch = 0
        
    def print_test_nearest_neighbors(self):
                
        nn_lists = self.model.nearest_neighbors(self.testwords, self.n_testwords_neighbors)
        
        # For each test word, print the most similar words.
        for w, nn_list in zip(self.testwords, nn_lists):
            print(w, end=':\n')
            for nn, sim in nn_list:
                print(f' {nn} ({sim:.3f})', end='')
            print()
        
        print('------------------------------------')
        
    def make_negative_sample(self, batch_size):
        neg_sample_ixs = torch.randint(len(self.ns_table), (batch_size, self.n_ns))
        return self.ns_table.take(neg_sample_ixs)
            
    def train(self):

        print_interval = 5000000
        
        while self.epoch < self.n_epochs:
            print(f'Epoch {self.epoch+1}.')

            # For diagnostics.
            n_pairs = 0
            sum_loss = 0
            total_pairs = 0
            n_batches = 0
            t0 = time.time()
            
            for t, c_pos in self.instance_gen.batches():

                batch_size = len(t)
                
                # Put the encoded target words and contexts into PyTorch tensors.
                t = torch.as_tensor(t)                
                c_pos = torch.as_tensor(c_pos)
                c_pos = c_pos.view(batch_size, 1)
                
                # Generate a sample of fake context words.
                # shape: (batch size, number of negative samples)
                c_neg = self.make_negative_sample(batch_size)
                
                # Combine positive and negative contexts.
                # shape: (batch size, 1 + nbr neg samples)
                c = torch.cat([c_pos, c_neg], dim=1)
                
                self.optimizer.zero_grad()

                # Compute the output from the model.
                # That is, the dot products between target embeddings
                # and context embeddings.
                scores = self.model(t, c)

                # Compute the loss with respect to the gold standard.
                loss = self.loss(scores, self.y[:batch_size])

                # Compute gradients and update the embeddings.
                loss.backward()
                self.optimizer.step()

                # We'll print some diagnostics periodically.
                sum_loss += loss.item()
                n_pairs += batch_size
                n_batches += 1
                if n_pairs > print_interval:
                    total_words = self.instance_gen.word_count
                    total_pairs += n_pairs
                    t1 = time.time()                    
                    print(f'Pairs: {total_pairs}, words: {total_words}, loss: {sum_loss / n_batches:.4f}, time: {t1-t0:.2f}')
                    self.print_test_nearest_neighbors()
                    n_pairs = 0
                    sum_loss = 0
                    n_batches = 0
                    t0 = time.time()
                    
            self.epoch += 1

# %% [markdown]
# ## Putting all the pieces together
#
# Now, we have all the pieces that we need to train the model. The following code just calls the other functions that we developed above. It also contains the parameters that control the program's behavior.
#
# To keep things fast, we'll just train on a small dataset. In a realistic implementation, we'd probably use a larger dataset and also run for several epochs.
#
# When we run this code, you will see that the similarity lists for the test words gradually start to make some sense. After an epoch, most of the lists should start to be sensible. The quality, particularly for infrequent words, will improve further if you use more training data.

# %%
model = None

def main():
    global model
    params = {
        'corpus': 'wikipedia_small/wikipedia.txt', # Training data file
        'device': 'cuda', # Device

        'n-neg-samples': 5, # Number of negative samples per positive sample
        'emb-dim': 64, # Embedding dimensionality
        
        'n-epochs': 2, # Number of epochs
        
        'batch-size': 1<<20, # Number of positive training instances in one batch
        'context-width': 5, # Maximal possible context width
        'prune-threshold': 1e-3, # Pruning threshold (see Mikolov's paper)
        'voc-size': 100000, # Maximal vocabulary size
        'ns-table-file': 'ns_table.txt', # Where to store the negative sampling table
        'ns-table-size': 1<<24, # Size of negative sampling table
        'ns-exp': 0.75, # Smoothing parameter for negative sampling distribution (see paper)
        'unknown-str': '<UNKNOWN>', # Dummy token for low-frequency words
        'lowercase': True, # Whether to lowercase the text
        'optimizer': 'adam', # Which gradient descent optimizer to use
        'lr': 1e-1, # Learning rate for the  optimizer

        # The test words for which we print the nearest neighbors periodically
        'testwords': ['apple', 'terrible', 'sweden', '1979', 'write', 'gothenburg'],
        # Number of nearest neighbors
        'n-testwords-neighbors': 5,
    }
    
    if params['device'] == 'cuda' and torch.cuda.is_available():
        torch.set_default_tensor_type(torch.cuda.FloatTensor)
        print('Running on CUDA device.')
    else:
        torch.set_default_tensor_type(torch.FloatTensor)
        print('Running on CPU.')

    # If we didn't already create the vocabulary and negative 
    # sampling table, we'll do that now.
    if os.path.exists(params['ns-table-file']):
        ns_table = load_ns_table(params['ns-table-file'])
    else:
        ns_table = make_ns_table(params)
        save_ns_table(ns_table, params['ns-table-file'])

    ctx_gen = SGNSContextGenerator(ns_table, params)
    model = SGNSModel(ctx_gen.voc, params)
    trainer = SGNSTrainer(ctx_gen, model, ns_table, params)

    trainer.train()
        
main()
# Out:
# Running on CUDA device.
# Building vocabulary and sampling table...
# .................... 1000000
# ..
# Epoch 1.
# Pairs: 5242880, words: 1447898, loss: 2.5763, time: 5.36
# apple:
#  culinary (0.536) pileggi (0.489) laila (0.478) mirko (0.467) mcgregor (0.461)
# terrible:
#  deputies (0.532) 1160 (0.478) nightjar (0.472) lofty (0.471) praise (0.455)
# sweden:
#  greeks (0.472) x-no-archive (0.469) ofsted (0.469) wadia (0.462) daoxuan (0.448)
# 1979:
#  economists (0.509) sephirot (0.504) engelm (0.492) spitzer (0.487) advises (0.482)
# write:
#  displeasure (0.488) kernot (0.470) ragnhild (0.463) hypsipyle (0.457) violons (0.456)
# gothenburg:
#  batu (0.503) 25,750 (0.490) inflexible (0.482) meadows (0.477) greek-letter (0.476)
# ------------------------------------
# Pairs: 10485760, words: 2891116, loss: 1.3468, time: 5.21
# apple:
#  weimar (0.526) pileggi (0.514) 1890 (0.507) culinary (0.504) autumnal (0.489)
# terrible:
#  deputies (0.537) hard (0.492) lofty (0.489) imminent (0.482) enhanced (0.482)
# sweden:
#  x-no-archive (0.493) wadia (0.492) cured (0.484) ring-porous (0.482) mathematician (0.475)
# 1979:
#  speaking (0.577) economists (0.565) few (0.555) dom (0.532) 1694 (0.515)
# write:
#  makes (0.577) byzantium (0.568) use (0.565) finally (0.557) erected (0.535)
# gothenburg:
#  daughter (0.555) 1686 (0.546) batu (0.525) relate (0.521) 1,037 (0.498)
# ------------------------------------
# Pairs: 15728640, words: 4329433, loss: 0.7696, time: 5.19
# apple:
#  1890 (0.593) weimar (0.586) jonathan (0.579) joined (0.570) angles (0.564)
# terrible:
#  remarkable (0.565) requirement (0.562) 1972 (0.562) enhanced (0.559) imminent (0.557)
# sweden:
#  them (0.594) special (0.584) lay (0.582) talk (0.578) mathematician (0.574)
# 1979:
#  wants (0.670) wing (0.656) thousands (0.656) receives (0.651) trained (0.629)
# write:
#  spoken (0.653) hear (0.641) byzantium (0.640) accord (0.637) sale (0.627)
# gothenburg:
#  1686 (0.569) referring (0.536) 1894 (0.533) daughter (0.528) batu (0.528)
# ------------------------------------
# Pairs: 20971520, words: 5778673, loss: 0.6136, time: 5.21
# apple:
#  jonathan (0.640) failure (0.629) prophet (0.616) angles (0.615) weimar (0.615)
# terrible:
#  conquest (0.627) remarkable (0.615) imminent (0.600) endowed (0.595) bengal (0.590)
# sweden:
#  huge (0.634) characters (0.606) 1845 (0.603) defined (0.593) ` (0.583)
# 1979:
#  broadway (0.623) homosexual (0.611) wants (0.606) thousands (0.598) transformation (0.596)
# write:
#  draws (0.634) loose (0.617) hear (0.603) weaknesses (0.602) solo (0.602)
# gothenburg:
#  1686 (0.567) 1894 (0.513) batu (0.513) craftsman (0.511) nitrile (0.511)
# ------------------------------------
# Pairs: 26214400, words: 7219706, loss: 0.5527, time: 5.12
# apple:
#  prophet (0.656) failure (0.632) weimar (0.618) walking (0.608) aerial (0.607)
# terrible:
#  conquest (0.638) referenda (0.613) bengal (0.599) m1 (0.599) endowed (0.598)
# sweden:
#  1845 (0.645) well (0.595) huge (0.587) lowest (0.579) ` (0.576)
# 1979:
#  candle (0.570) viewers (0.550) television (0.535) african (0.531) unu (0.529)
# write:
#  cosmic (0.644) solo (0.603) identification (0.596) supervision (0.590) upwards (0.589)
# gothenburg:
#  1686 (0.559) monopolies (0.518) hartley (0.506) demolishing (0.506) craftsman (0.505)
# ------------------------------------
# Pairs: 31457280, words: 8650602, loss: 0.5225, time: 5.12
# apple:
#  prophet (0.635) noble (0.589) fiddle (0.587) ladies (0.581) weimar (0.580)
# terrible:
#  referenda (0.608) conquest (0.585) m1 (0.581) mda (0.572) endowed (0.565)
# sweden:
#  1845 (0.627) ` (0.608) fujian (0.571) 1956 (0.568) mountain (0.566)
# 1979:
#  candle (0.595) television (0.574) u.p (0.565) mitosis (0.560) terse (0.559)
# write:
#  cosmic (0.686) solo (0.671) seamlessly (0.651) try (0.627) revelation (0.619)
# gothenburg:
#  1686 (0.549) entangled (0.529) monopolies (0.520) obsessive (0.513) demolishing (0.507)
# ------------------------------------
# Pairs: 36700160, words: 9994339, loss: 0.5241, time: 4.96
# apple:
#  temperament (0.580) fiddle (0.579) prophet (0.572) dinosaurs (0.561) ferrand (0.561)
# terrible:
#  referenda (0.560) geisha (0.551) mda (0.551) amplifying (0.540) lander (0.536)
# sweden:
#  -rrb- (0.702) henry (0.692) 13 (0.681) norway (0.677) french (0.665)
# 1979:
#  october (0.658) pierre (0.653) jean (0.645) 5 (0.634) 29 (0.631)
# write:
#  solo (0.686) try (0.666) seamlessly (0.659) necessarily (0.642) give (0.626)
# gothenburg:
#  entangled (0.543) 1686 (0.527) monopolies (0.518) obsessive (0.518) demolishing (0.511)
# ------------------------------------
# Pairs: 41943040, words: 11442737, loss: 0.5155, time: 5.17
# apple:
#  fiddle (0.567) temperament (0.563) ferrand (0.551) video-game (0.550) saws (0.548)
# terrible:
#  geisha (0.546) amplifying (0.534) referenda (0.533) mda (0.530) face-to-face (0.528)
# sweden:
#  charles (0.794) 13 (0.794) france (0.791) norway (0.770) henry (0.766)
# 1979:
#  5 (0.705) jean (0.702) theologian (0.700) frederick (0.681) 1943 (0.680)
# write:
#  try (0.642) then (0.628) character (0.622) necessarily (0.616) less (0.613)
# gothenburg:
#  entangled (0.541) fated (0.514) bridgestone (0.514) obsessive (0.511) forgettable (0.506)
# ------------------------------------
# Pairs: 47185920, words: 12878202, loss: 0.4908, time: 5.13
# apple:
#  temperament (0.552) fiddle (0.544) ferrand (0.540) saws (0.534) calmer (0.533)
# terrible:
#  less (0.633) it (0.612) orbit (0.606) referenda (0.600) merely (0.570)
# sweden:
#  charles (0.796) 13 (0.774) frederick (0.771) 29 (0.762) john (0.759)
# 1979:
#  5 (0.697) theologian (0.694) duke (0.694) 1992 (0.688) 1996 (0.688)
# write:
#  look (0.689) try (0.683) character (0.676) less (0.669) then (0.662)
# gothenburg:
#  entangled (0.534) bridgestone (0.533) obsessive (0.523) fated (0.518) humid (0.510)
# ------------------------------------
# Pairs: 52428800, words: 14423802, loss: 0.4546, time: 5.20
# apple:
#  failure (0.559) temperament (0.555) anger (0.549) gives (0.548) taliban (0.543)
# terrible:
#  less (0.721) it (0.676) send (0.673) extremely (0.673) actually (0.655)
# sweden:
#  frederick (0.743) swedish (0.731) charles (0.727) 1931 (0.725) 29 (0.718)
# 1979:
#  1992 (0.760) 1977 (0.739) 1939 (0.734) 1999 (0.730) 1996 (0.720)
# write:
#  look (0.742) bad (0.733) whatever (0.729) try (0.727) asked (0.726)
# gothenburg:
#  obsessive (0.548) bridgestone (0.543) travelers (0.531) kelp (0.528) humid (0.519)
# ------------------------------------
# Pairs: 57671680, words: 16081772, loss: 0.3176, time: 5.21
# apple:
#  failure (0.582) anger (0.567) gives (0.561) temperament (0.558) taliban (0.544)
# terrible:
#  less (0.724) extremely (0.723) send (0.711) sound (0.666) periods (0.666)
# sweden:
#  saint (0.683) swedish (0.679) wales (0.674) germany (0.654) recognised (0.653)
# 1979:
#  1992 (0.777) 1994 (0.772) 1977 (0.769) 1975 (0.752) 1939 (0.751)
# write:
#  whatever (0.764) bad (0.759) look (0.746) take (0.744) think (0.743)
# gothenburg:
#  obsessive (0.539) bridgestone (0.523) kelp (0.517) travelers (0.511) chastened (0.505)
# ------------------------------------
# Pairs: 62914560, words: 17739585, loss: 0.2457, time: 5.19
# apple:
#  failure (0.594) anger (0.577) gives (0.569) temperament (0.558) toured (0.546)
# terrible:
#  extremely (0.724) send (0.713) less (0.678) periods (0.669) carrying (0.662)
# sweden:
#  makeup (0.690) also (0.677) movement (0.671) dominion (0.669) kingdom (0.661)
# 1979:
#  1994 (0.784) 1992 (0.769) 1977 (0.768) 1975 (0.762) 1999 (0.744)
# write:
#  whatever (0.754) wish (0.742) think (0.736) take (0.725) appear (0.719)
# gothenburg:
#  rtos (0.496) quisling (0.465) slid (0.465) robocode (0.464) toned (0.463)
# ------------------------------------
# Pairs: 68157440, words: 19292512, loss: 0.3681, time: 5.20
# apple:
#  failure (0.596) anger (0.582) gives (0.574) temperament (0.555) toured (0.550)
# terrible:
#  send (0.685) extremely (0.671) slowly (0.648) slightly (0.636) carrying (0.629)
# sweden:
#  development (0.696) site (0.686) movement (0.684) also (0.677) swedish (0.675)
# 1979:
#  1994 (0.777) 1993 (0.769) 1992 (0.761) 1977 (0.751) 1975 (0.743)
# write:
#  wish (0.740) take (0.739) whatever (0.726) think (0.712) we (0.702)
# gothenburg:
#  kiel (0.509) rtos (0.505) quisling (0.481) betty (0.467) uzala (0.465)
# ------------------------------------
# Pairs: 73400320, words: 20710780, loss: 0.5198, time: 5.08
# apple:
#  failure (0.602) anger (0.579) gives (0.571) attributes (0.558) production (0.553)
# terrible:
#  slowly (0.662) send (0.654) extremely (0.648) largely (0.644) considered (0.642)
# sweden:
#  site (0.693) official (0.657) development (0.648) operates (0.626) establishing (0.625)
# 1979:
#  1999 (0.803) 1993 (0.790) 1986 (0.777) 1956 (0.775) 1977 (0.771)
# write:
#  wish (0.751) take (0.735) want (0.735) whatever (0.728) anyone (0.723)
# gothenburg:
#  muskogee (0.583) heavener (0.581) 454 (0.575) 50.1 (0.575) '38 (0.572)
# ------------------------------------
# Pairs: 78643200, words: 22128574, loss: 0.4804, time: 5.06
# apple:
#  failure (0.597) production (0.573) gives (0.567) anger (0.560) attributes (0.555)
# terrible:
#  slowly (0.707) extremely (0.688) largely (0.687) bringing (0.670) actually (0.668)
# sweden:
#  site (0.717) municipalities (0.703) province (0.701) capital (0.680) finland (0.675)
# 1979:
#  1999 (0.849) 1975 (0.830) 1982 (0.828) 1986 (0.828) 1976 (0.824)
# write:
#  wish (0.774) whatever (0.770) think (0.764) appear (0.762) want (0.760)
# gothenburg:
#  newfoundland (0.654) ontario (0.638) westmoreland (0.633) '38 (0.628) lyndhurst (0.625)
# ------------------------------------
# Pairs: 83886080, words: 23547217, loss: 0.4653, time: 5.07
# apple:
#  failure (0.583) anger (0.575) attributes (0.569) net (0.561) temperament (0.559)
# terrible:
#  elsewhere (0.669) largely (0.665) slowly (0.657) success (0.656) considered (0.656)
# sweden:
#  province (0.755) municipalities (0.736) finland (0.723) capital (0.717) egypt (0.665)
# 1979:
#  1982 (0.867) 1975 (0.860) 1992 (0.855) 1989 (0.854) 1999 (0.853)
# write:
#  something (0.791) nothing (0.760) because (0.757) wish (0.754) ask (0.753)
# gothenburg:
#  serbs (0.656) ungava (0.654) newfoundland (0.647) westmoreland (0.642) '38 (0.639)
# ------------------------------------
# Pairs: 89128960, words: 24976391, loss: 0.4587, time: 5.21
# apple:
#  anger (0.574) selection (0.573) failure (0.570) temperament (0.564) audio (0.561)
# terrible:
#  success (0.667) considered (0.640) scene (0.637) involved (0.637) course (0.636)
# sweden:
#  capital (0.726) municipalities (0.719) province (0.716) finland (0.714) egypt (0.711)
# 1979:
#  1991 (0.869) 1975 (0.869) 1964 (0.865) 1989 (0.858) 1992 (0.858)
# write:
#  something (0.798) nothing (0.786) wish (0.764) saying (0.763) ask (0.759)
# gothenburg:
#  hatton (0.647) ungava (0.638) kiel (0.629) severn (0.628) schnapf (0.625)
# ------------------------------------
# Pairs: 94371840, words: 26412664, loss: 0.4455, time: 5.17
# apple:
#  selection (0.585) audio (0.577) duracell (0.562) anger (0.559) analogue (0.558)
# terrible:
#  life (0.648) success (0.643) presence (0.634) involved (0.630) conquest (0.616)
# sweden:
#  greece (0.730) capital (0.721) egypt (0.717) finland (0.717) italy (0.708)
# 1979:
#  1980 (0.881) 1975 (0.878) 1977 (0.875) 1991 (0.870) 1992 (0.869)
# write:
#  saying (0.795) ask (0.794) something (0.791) wish (0.789) nothing (0.785)
# gothenburg:
#  kiel (0.613) algood (0.608) hatton (0.606) muskogee (0.604) severn (0.602)
# ------------------------------------
# End of file.
# Epoch 2.
# Pairs: 5242880, words: 1448835, loss: 0.4309, time: 5.08
# apple:
#  hd (0.582) duracell (0.574) audio (0.555) net (0.552) periodicity (0.552)
# terrible:
#  death (0.663) saw (0.659) life (0.655) incident (0.654) rome (0.649)
# sweden:
#  finland (0.758) province (0.711) italy (0.703) poland (0.684) capital (0.667)
# 1979:
#  1980 (0.928) 1971 (0.922) 1977 (0.900) 1973 (0.893) 1975 (0.892)
# write:
#  ask (0.794) how (0.793) saying (0.786) telling (0.778) wanted (0.769)
# gothenburg:
#  morrow (0.582) algood (0.582) muskogee (0.567) erie (0.567) findlay (0.563)
# ------------------------------------
# Pairs: 10485760, words: 2891232, loss: 0.4231, time: 5.05
# apple:
#  duracell (0.593) searching (0.581) hd (0.576) marketing (0.549) audio (0.548)
# terrible:
#  saw (0.659) but (0.657) incident (0.655) probably (0.654) showed (0.645)
# sweden:
#  finland (0.804) province (0.714) italy (0.697) norway (0.696) poland (0.696)
# 1979:
#  1980 (0.944) 1971 (0.930) 1983 (0.918) 1977 (0.916) 1972 (0.909)
# write:
#  how (0.799) saying (0.759) ask (0.755) we (0.753) telling (0.750)
# gothenburg:
#  morrow (0.577) algood (0.568) erie (0.562) findlay (0.553) hardeman (0.550)
# ------------------------------------
# Pairs: 15728640, words: 4330410, loss: 0.4150, time: 5.04
# apple:
#  duracell (0.609) searching (0.566) hd (0.560) logged (0.558) coordinated (0.550)
# terrible:
#  but (0.650) soon (0.648) death (0.641) just (0.637) completely (0.637)
# sweden:
#  finland (0.826) norway (0.741) province (0.718) lithuania (0.705) poland (0.703)
# 1979:
#  1980 (0.930) 1978 (0.913) 1983 (0.912) 1971 (0.912) 1973 (0.904)
# write:
#  how (0.804) read (0.787) readers (0.753) things (0.751) telling (0.747)
# gothenburg:
#  morrow (0.569) algood (0.556) erie (0.550) hardeman (0.548) findlay (0.547)
# ------------------------------------
# Pairs: 20971520, words: 5777925, loss: 0.4113, time: 5.13
# apple:
#  duracell (0.612) logged (0.579) intel (0.561) 8-bit (0.558) coordinated (0.552)
# terrible:
#  prisoner (0.649) just (0.647) shame (0.640) immediately (0.633) attitude (0.626)
# sweden:
#  finland (0.834) norway (0.756) slovakia (0.742) province (0.733) germany (0.724)
# 1979:
#  1978 (0.904) 1980 (0.903) 1982 (0.898) 1973 (0.886) 1983 (0.883)
# write:
#  read (0.820) how (0.791) things (0.750) add (0.736) readers (0.727)
# gothenburg:
#  morrow (0.569) shattuck (0.566) erie (0.556) hardeman (0.555) gaul (0.554)
# ------------------------------------
# Pairs: 26214400, words: 7217599, loss: 0.4100, time: 5.18
# apple:
#  duracell (0.614) logged (0.592) 8-bit (0.574) intel (0.574) hd (0.553)
# terrible:
#  shame (0.686) seeing (0.668) attitude (0.664) something (0.662) feeling (0.661)
# sweden:
#  finland (0.842) norway (0.775) slovakia (0.759) province (0.755) germany (0.755)
# 1979:
#  1978 (0.899) 1980 (0.885) 1973 (0.869) 1991 (0.865) 1986 (0.862)
# write:
#  read (0.824) how (0.766) things (0.723) readers (0.717) look (0.711)
# gothenburg:
#  shattuck (0.570) algood (0.562) gaul (0.558) morrow (0.553) erie (0.550)
# ------------------------------------
# Pairs: 31457280, words: 8648171, loss: 0.4127, time: 5.12
# apple:
#  duracell (0.615) hd (0.590) 8-bit (0.589) intel (0.589) logged (0.575)
# terrible:
#  shame (0.697) seeing (0.674) attitude (0.671) too (0.670) desire (0.669)
# sweden:
#  finland (0.835) norway (0.807) slovakia (0.776) province (0.771) netherlands (0.762)
# 1979:
#  1978 (0.890) 1991 (0.874) 1977 (0.868) 1987 (0.867) 1986 (0.862)
# write:
#  read (0.851) how (0.782) add (0.754) readers (0.749) look (0.741)
# gothenburg:
#  algood (0.566) shattuck (0.564) bonna (0.554) monument (0.548) ungava (0.545)
# ------------------------------------
# Pairs: 36700160, words: 9992115, loss: 0.4091, time: 4.97
# apple:
#  duracell (0.612) intel (0.605) hd (0.605) risc (0.599) 8-bit (0.592)
# terrible:
#  shame (0.693) desire (0.665) seeing (0.654) fear (0.651) seriously (0.644)
# sweden:
#  norway (0.820) denmark (0.788) germany (0.766) becomes (0.764) netherlands (0.762)
# 1979:
#  1991 (0.907) 1986 (0.902) 1977 (0.899) 1978 (0.896) 1981 (0.894)
# write:
#  read (0.842) how (0.775) look (0.759) add (0.755) make (0.750)
# gothenburg:
#  bonna (0.568) jacek (0.567) algood (0.564) shattuck (0.557) vatican (0.556)
# ------------------------------------
# Pairs: 41943040, words: 11440076, loss: 0.4427, time: 5.10
# apple:
#  intel (0.622) hd (0.616) risc (0.611) duracell (0.602) 8-bit (0.601)
# terrible:
#  fled (0.713) shame (0.705) himself (0.701) fear (0.700) when (0.693)
# sweden:
#  denmark (0.814) becomes (0.785) prince (0.763) poland (0.761) belgium (0.750)
# 1979:
#  1978 (0.869) 1986 (0.868) 1976 (0.864) 1980 (0.857) 1988 (0.856)
# write:
#  read (0.835) make (0.774) how (0.764) look (0.743) add (0.742)
# gothenburg:
#  jacek (0.572) bonna (0.570) vasa (0.567) jewett (0.566) algood (0.560)
# ------------------------------------
# Pairs: 47185920, words: 12875375, loss: 0.4285, time: 5.07
# apple:
#  intel (0.650) hd (0.638) risc (0.619) 8-bit (0.609) pc (0.604)
# terrible:
#  death (0.735) fled (0.733) rebellion (0.725) ascended (0.725) him (0.717)
# sweden:
#  denmark (0.791) 1752 (0.750) becomes (0.728) aragon (0.722) saxony (0.721)
# 1979:
#  1986 (0.901) 1977 (0.897) 1978 (0.894) 1980 (0.886) 1982 (0.884)
# write:
#  read (0.826) make (0.783) follow (0.773) readers (0.756) give (0.754)
# gothenburg:
#  jewett (0.577) jacek (0.572) bonna (0.567) 1636 (0.565) algood (0.563)
# ------------------------------------
# Pairs: 52428800, words: 14420283, loss: 0.3716, time: 5.15
# apple:
#  intel (0.673) hd (0.652) discontinued (0.642) pc (0.642) hardware (0.625)
# terrible:
#  death (0.748) rebellion (0.727) kill (0.708) him (0.706) fled (0.702)
# sweden:
#  denmark (0.759) 1752 (0.688) austria (0.684) belgium (0.682) iv (0.675)
# 1979:
#  1986 (0.912) 1977 (0.907) 1980 (0.905) 1995 (0.904) 1973 (0.901)
# write:
#  read (0.818) make (0.758) comments (0.758) follow (0.753) readers (0.753)
# gothenburg:
#  1636 (0.575) algood (0.567) unincorporated (0.556) bonna (0.556) jacek (0.554)
# ------------------------------------
# Pairs: 57671680, words: 16077384, loss: 0.2401, time: 5.22
# apple:
#  intel (0.669) discontinued (0.658) hardware (0.648) hd (0.644) introduced (0.639)
# terrible:
#  death (0.714) rebellion (0.707) kill (0.692) him (0.684) dying (0.683)
# sweden:
#  municipality (0.771) municipalities (0.745) denmark (0.675) municipal (0.672) website (0.667)
# 1979:
#  1995 (0.907) 1986 (0.904) 1973 (0.900) 1980 (0.894) 1988 (0.875)
# write:
#  read (0.805) comments (0.760) make (0.738) readers (0.738) give (0.735)
# gothenburg:
#  unincorporated (0.577) sweden (0.567) lebanon (0.563) erie (0.561) algood (0.553)
# ------------------------------------
# Pairs: 62914560, words: 17733323, loss: 0.2131, time: 5.17
# apple:
#  intel (0.664) discontinued (0.662) hardware (0.657) introduced (0.646) hd (0.634)
# terrible:
#  rebellion (0.681) dying (0.679) suffering (0.677) violent (0.674) kill (0.669)
# sweden:
#  site (0.826) borders (0.766) summit (0.760) links (0.759) central (0.756)
# 1979:
#  1995 (0.904) 1986 (0.893) 1973 (0.893) 1980 (0.884) 1983 (0.866)
# write:
#  read (0.800) comments (0.758) give (0.733) idea (0.732) take (0.732)
# gothenburg:
#  erie (0.631) sweden (0.608) peninsula (0.600) kiel (0.593) geneva (0.578)
# ------------------------------------
# Pairs: 68157440, words: 19287379, loss: 0.3367, time: 5.11
# apple:
#  discontinued (0.667) intel (0.667) hardware (0.664) introduced (0.647) real-time (0.630)
# terrible:
#  violent (0.677) suffering (0.677) dying (0.663) kidnapping (0.663) victim (0.661)
# sweden:
#  site (0.808) borders (0.799) northern (0.766) central (0.766) columbus (0.759)
# 1979:
#  1995 (0.902) 1973 (0.889) 1986 (0.888) 1983 (0.869) 1981 (0.868)
# write:
#  read (0.807) comments (0.750) take (0.741) asking (0.737) idea (0.733)
# gothenburg:
#  erie (0.636) peninsula (0.626) stockholm (0.624) hampton (0.619) sweden (0.613)
# ------------------------------------
# Pairs: 73400320, words: 20705713, loss: 0.4733, time: 5.10
# apple:
#  intel (0.678) discontinued (0.665) hardware (0.654) audio (0.640) sony (0.638)
# terrible:
#  causing (0.698) escape (0.691) incident (0.684) heart (0.672) bitter (0.664)
# sweden:
#  municipality (0.842) borders (0.749) swedish (0.749) site (0.741) northern (0.733)
# 1979:
#  1995 (0.906) 1973 (0.904) 1985 (0.889) 1988 (0.889) 1986 (0.889)
# write:
#  read (0.843) follow (0.776) how (0.761) saying (0.750) think (0.749)
# gothenburg:
#  norrköping (0.651) erie (0.631) lebanon (0.620) stockholm (0.618) peninsula (0.612)
# ------------------------------------
# Pairs: 78643200, words: 22124377, loss: 0.4360, time: 5.13
# apple:
#  intel (0.684) discontinued (0.657) audio (0.650) sony (0.634) hardware (0.632)
# terrible:
#  search (0.700) save (0.671) possibly (0.670) seeing (0.669) mercy (0.666)
# sweden:
#  municipality (0.857) municipalities (0.755) borders (0.754) provinces (0.752) province (0.735)
# 1979:
#  1983 (0.901) 1980 (0.896) 1982 (0.896) 1975 (0.894) 1985 (0.894)
# write:
#  read (0.845) follow (0.804) what (0.768) reader (0.760) say (0.746)
# gothenburg:
#  norrköping (0.667) erie (0.650) luleå (0.631) lachine (0.620) dekalb (0.609)
# ------------------------------------
# Pairs: 83886080, words: 23543877, loss: 0.4279, time: 5.15
# apple:
#  intel (0.680) discontinued (0.630) audio (0.624) sony (0.618) cassette (0.616)
# terrible:
#  deception (0.653) engaging (0.645) mercy (0.643) suffering (0.640) possibly (0.633)
# sweden:
#  provinces (0.805) municipality (0.785) finland (0.778) borders (0.768) municipalities (0.743)
# 1979:
#  1993 (0.908) 1983 (0.893) 1985 (0.892) 1982 (0.890) 1980 (0.888)
# write:
#  read (0.850) follow (0.787) what (0.775) say (0.755) reader (0.751)
# gothenburg:
#  erie (0.674) norrköping (0.664) luleå (0.631) lachine (0.620) vasa (0.608)
# ------------------------------------
# Pairs: 89128960, words: 24973189, loss: 0.4260, time: 5.04
# apple:
#  intel (0.701) hd (0.644) emulator (0.640) desktop (0.636) audio (0.628)
# terrible:
#  avoiding (0.636) engaging (0.628) suffering (0.623) shortness (0.613) sees (0.596)
# sweden:
#  provinces (0.812) finland (0.791) borders (0.764) province (0.695) municipality (0.693)
# 1979:
#  1982 (0.891) 1980 (0.891) 1976 (0.885) 1993 (0.884) 1987 (0.880)
# write:
#  read (0.855) follow (0.760) what (0.756) say (0.750) doing (0.749)
# gothenburg:
#  erie (0.673) norrköping (0.630) dekalb (0.593) luleå (0.592) lufthansa (0.584)
# ------------------------------------
# Pairs: 94371840, words: 26409302, loss: 0.4172, time: 5.09
# apple:
#  intel (0.714) hd (0.663) audio (0.647) desktop (0.642) emulator (0.640)
# terrible:
#  shortness (0.632) suffering (0.620) engaging (0.610) anger (0.606) retribution (0.602)
# sweden:
#  finland (0.782) provinces (0.755) borders (0.721) ireland (0.668) swedish (0.668)
# 1979:
#  1982 (0.882) 1985 (0.871) 1990 (0.871) 1980 (0.870) 1976 (0.870)
# write:
#  read (0.832) publish (0.737) learn (0.731) how (0.729) teach (0.727)
# gothenburg:
#  erie (0.640) frankfurt (0.622) lufthansa (0.614) norrköping (0.580) nogales (0.568)
# ------------------------------------
# End of file.

# %% [markdown]
# ## Inspecting the result
#
# In addition to the examples above, we can also inspect the results interactively. For instance, we can show the nearest-neighbor lists (according to the cosine similarity) of some other test words.

# %%
model.nearest_neighbors(['potato'], 5)
# Out:
# [[('meat', 0.783933699131012),
#   ('rice', 0.7583475708961487),
#   ('potatoes', 0.7371722459793091),
#   ('vegetables', 0.7323728203773499),
#   ('cooking', 0.7291325330734253)]]

# %% [markdown]
# We can also show the cosine similarity for a given pair of words. Apparently, a *dog* is distributionally more similar to a *cat* than to a *gorilla*.

# %%
model.cosine_similarity('dog', 'cat')
# Out:
# 0.520124614238739

# %%
model.cosine_similarity('dog', 'gorilla')
# Out:
# 0.4750337600708008
